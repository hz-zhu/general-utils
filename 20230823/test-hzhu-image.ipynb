# %%
from hzhu_image import *
import numpy as np

hutil.disp(np_version=np.__version__)
# Out:
# np_version = 1.21.2

# %%
path = '/Users/corneliuszhu/Pictures/Lightroom/Gallery/IMG_4358-1.jpg'
img = HImage.from_path(path)

hutil.disp(shape=img.shape)
hutil.disp(len_shape=len(img.shape))
plt.figure()
img.plot()

hutil.disp(deep_copy=img.deep_copy)
hutil.disp(img)
hutil.disp(type(img.C))
# Out:
# shape = (4000, 4000, 3)
# len_shape = 3
# deep_copy = True
# <HImage> shape=(4000, 4000, 3), dtype=uint8, deep_copy=True
# <class 'int'>

# %%
hutil.disp(f"{img.to_tensor(channel_first=True).shape = }")
hutil.disp(f"{img.to_tensor(channel_first=False).shape = }")

hvec = HVec(5)
print(hvec)
print(hvec.shape)
hvec.check_shape()

hvec = HVec.from_numbers(1,2,3)
print(hvec)
print('')

hvec2 = HVec2.from_numbers(1,3)
print(hvec2)
print(type(hvec2))
print(hvec2.x, hvec2.y)
print('')

hvec2 = HVec2.from_iterable([1,3])
hvec2 = hvec2.repeat(2)[1:3]
print(hvec2)
print(type(hvec2))
print(hvec2.x, hvec2.y)
# Out:
# img.to_tensor(channel_first=True).shape = torch.Size([3, 4000, 4000])
# img.to_tensor(channel_first=False).shape = torch.Size([4000, 4000, 3])
# [ 1.   2.   2.5  5.  10. ]
# (5,)
# [1. 2. 3.]
#
# [1. 3.]
# <class 'hzhu_image.HVec2'>
# 1.0 3.0
#
# [1. 3.]
# <class 'hzhu_image.HVec2'>
# 1.0 3.0
